# %% [markdown]
# <a href="https://colab.research.google.com/github/s1290020/movie_sommelier/blob/main/movie.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import pandas as pd
import time

# ブラウザの起動
chromedriver = "chromedriver.exe"
service = Service(execureviews_path=chromedriver)
driver = webdriver.Chrome(service=service)
url = "https://eiga.com/movie/91918/review/"
driver.get(url)

# データを取得し、配列に格納する
reviews = []
is_continue = True
while(is_continue):
  text_elems = driver.find_elements(By.CLASS_NAME, "txt-block")
  for text_i in text_elems:
    text = text_i.get_attribute("textContent")
    if '続きを読む' in text:
      text = text.replace("…","").replace("続きを読む","")
    if 'ネタバレ！ クリックして本文を読む' in text:
      text = text.replace("ネタバレ！ クリックして本文を読む","")

    # 配列にデータを格納
    reviews.append(text)

  #　次へボタンが押せなければループを終了、押せるなら押して次のページへ
  if driver.find_elements(By.CSS_SELECTOR, ".next.icon-after.disabled"):
    is_continue = False
  else:
    next_button = driver.find_element(By.CSS_SELECTOR, ".next.icon-after")
    next_button.click()
    time.sleep(2)

#　配列からDataFrameを作成し、csvで出力する
df = pd.DataFrame(reviews, columns=['レビュー'])
df.index.name = 'index'
df.to_csv("無限列車編_レビュー.csv", encoding="utf-8")

#ブラウザの終了
driver.quit()
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for chromedriver_binary: filename=chromedriver_binary-122.0.6261.57.0-py3-none-any.whl size=7920751 sha256=756d66160361b38546e45bbfb2aeaa9ae18a24971ab907b6a455a3dd31fca5b5
#   Stored in directory: /root/.cache/pip/wheels/14/92/c2/1ebe8ea0290825cd44fa595c86e18b767a6de19b3120cc5b60
# Successfully built chromedriver_binary
# ...
#   Attempting uninstall: chromedriver_binary
#     Found existing installation: chromedriver-binary 123.0.6312.4.0
#     Uninstalling chromedriver-binary-123.0.6312.4.0:
#       Successfully uninstalled chromedriver-binary-123.0.6312.4.0
# ...
# WARNING:selenium.webdriver.common.selenium_manager:The chromedriver version (114.0.5735.90) detected in PATH at /usr/local/bin/chromedriver might not be compatible with the detected chrome version (122.0.6261.57); currently, chromedriver 122.0.6261.57 is recommended for chrome 122.*, so it is advised to delete the driver in PATH and retry
# ...

# %%
# Filmarksのスクレイピング
# 対象映画は「名探偵ピカチュウ」
from bs4 import BeautifulSoup
from urllib import request
import pandas as pd
import re
df_list = []
pages = range(100)

for page in pages:
    url = 'https://filmarks.com/movies/77543/no_spoiler?page='+str(page)+'' #ネタバレなし読み込み

    response = request.urlopen(url)
    soup = BeautifulSoup(response)
    response.close()

    # レビューゾーンのスクレイピング
    # class属性が「p-main-area p-timeline」のdivタグを検索する
    p_main_area = soup.find('div', class_='p-main-area p-timeline')

    # class属性が「c-rating__score」であるdivタグを検索する
    score = p_main_area.find_all('div', class_='c-rating__score')

    # class属性が「p-mark__review」であるdivタグを検索する
    review = p_main_area.find_all('div', class_='p-mark__review')
    #if p-mark__review内に、続きを読むがあるなら
    #a href の指している内容をreviewの内容として書き換えよう

    for i in range(len(review)):
        _df = pd.DataFrame({'score': [score[i].text],
                            'review': [review[i].text]})
        df_list.append(_df)

    print("page%s is over"%page )

# 一つのデータフレームにまとめる
df_review = pd.concat(df_list).reset_index(drop=True)
print(df_review.shape)
df_review.head()
# Out:
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page0 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page1 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page2 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page3 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page4 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page5 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page6 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page7 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page8 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page9 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page10 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page11 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page12 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page13 is over
# <a href="/movies/77543/no_spoiler">ネタバレなし</a>
# page14 is over
# ...

# %%
import pandas as pd
df_list = []
pages = range(1,101)

for page in pages:
    url = 'https://filmarks.com/movies/77543?page='+str(page)+''

    response = request.urlopen(url)
    soup = BeautifulSoup(response)
    response.close()

    # レビューゾーンのスクレイピング
    # class属性が「p-main-area p-timeline」のdivタグを検索する
    p_main_area = soup.find('div', class_='p-main-area p-timeline')

    # class属性が「p-mark__review」であるdivタグを検索する
    score = p_main_area.find_all('div', class_='c-rating__score')
    review = p_main_area.find_all('div', class_='p-mark__review')

    for i in range(len(review)):
        print(review[i])
          #new_url = 'https://filmarks.com/'+str(link)+''
          #response = request.urlopen(new_url)
          #soup = BeautifulSoup(response)
          #response.close()

          #review = p_main_area.find_all('div', class_='p-mark__review')
        _df = pd.DataFrame({'score': [score[i].text],
                            'review': [review[i].text]})
        df_list.append(_df)

    print("page%s is over"%page )

# 一つのデータフレームにまとめる
df_review = pd.concat(df_list).reset_index(drop=True)
print(df_review.shape)
df_review.head()


# スコアがない場合は０を入れる
df_review['score'].replace("-", 0 ,inplace=True)

# スコアを数値化
df_review['score'] = df_review['score'].astype(float)

# スクレイピングしたデータフレームをcsv形式で保存
df_review.to_csv('filmarks_review_pikachu.csv', index=False, encoding='utf_8_sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-387f381a93ae> in <cell line: 5>()
#       6     url = 'https://filmarks.com/movies/77543?page='+str(page)+''
#       7
# ----> 8     response = request.urlopen(url)
#       9     soup = BeautifulSoup(response)
#      10     response.close()
#
# NameError: name 'request' is not defined

# %%
#ファンタジー映画　2024~1994　の30年間分
from bs4 import BeautifulSoup
from urllib import request
import pandas as pd
df_list = []

URLS = ['https://filmarks.com/movies/99089',#2023
        'https://filmarks.com/movies/66996',#2023
        'https://filmarks.com/movies/60432',#2022
        'https://filmarks.com/movies/86030',#2021
        'https://filmarks.com/movies/75029',#2020
        'https://filmarks.com/movies/88417',#2019
        'https://filmarks.com/movies/77543',#2019
        'https://filmarks.com/movies/82978',#2019
        'https://filmarks.com/movies/68424',#2018
        'https://filmarks.com/movies/73566',#2017
        'https://filmarks.com/movies/69153',#2017
        'https://filmarks.com/movies/60428',#2016
        'https://filmarks.com/movies/56401',#2015
        'https://filmarks.com/movies/54194',#2014
        'https://filmarks.com/movies/54571',#2013
        'https://filmarks.com/movies/52997',#2012
        'https://filmarks.com/movies/21414',#2012
        'https://filmarks.com/movies/26112',#2011
        'https://filmarks.com/movies/26793',#2010
        'https://filmarks.com/movies/30436',#2010
        'https://filmarks.com/movies/7499',#2009
        'https://filmarks.com/movies/17694',#2008
        'https://filmarks.com/movies/537',#2008
        'https://filmarks.com/movies/16673',#2007
        'https://filmarks.com/movies/17571',#2006
        'https://filmarks.com/movies/3965',#2005
        'https://filmarks.com/movies/35140',#2004
        'https://filmarks.com/movies/36505',#2003
        'https://filmarks.com/movies/16650',#2002
        'https://filmarks.com/movies/14348',#2001
        'https://filmarks.com/movies/37928',#2000
        'https://filmarks.com/movies/16900',#1999
        'https://filmarks.com/movies/55394',#1998
        'https://filmarks.com/movies/19926',#1997
        'https://filmarks.com/movies/343',#1996
        'https://filmarks.com/movies/30931',#1995
        'https://filmarks.com/movies/6014',#1994
]

for url in URLS:
  response = request.urlopen(url)
  soup = BeautifulSoup(response)
  response.close()

  # レビューゾーンのスクレイピング
  # class属性が「p-content-detail__title」のspanタグを検索する
  title = soup.find('h2', class_='p-content-detail__title').find('span')
  # class属性が「p-content-detail__title」のaタグを検索する
  year = soup.find('h2', class_='p-content-detail__title').find('a')
  # class属性が「genres」のulタグを検索する
  genle = soup.find('ul', class_='genres')
  # class属性が「c-content__jacket image」のdivタグを検索する
  picture = soup.find('a', class_='c-content__jacket').find('img').get('src')
  # class属性が「p-main-area p-timeline」のdivタグを検索する
  p_main_area = soup.find('div', class_='p-main-area p-timeline')
  # class属性が「p-main-area p-content-detail-highlight__body」のdivタグを検索する
  highlight = p_main_area.find('div', class_="p-content-detail-highlight__body")
  if highlight != None:
    highlight = highlight.text

  #あとから追加します、画像データ
  wordcloud = None

  # class属性が「p-mark__review」であるdivタグを検索する
  #score = p_main_area.find_all('div', class_='c-rating__score')
  #review = p_main_area.find_all('div', class_='p-mark__review')

  #for i in range(len(review)):
  #   _df = pd.DataFrame({'score': [score[i].text],
  #                       'review': [review[i].text]})
  #   df_list.append(_df)

  _df = pd.DataFrame({'Title': [title.text],
                      'Year': [year.text],
                      'Genle': [genle.text],
                      'Picture': [picture],
                      'Highlight': [highlight],
                      'Wordcloud':[wordcloud]})
  df_list.append(_df)

  print("page%s is over"%url)

# 一つのデータフレームにまとめる
df_review = pd.concat(df_list).reset_index(drop=True)
print(df_review.shape)
df_review.head()

# スクレイピングしたデータフレームをcsv形式で保存
df_review.to_csv('movie_fantasy.csv', index=False, encoding='utf_8_sig')
# Out:
# pagehttps://filmarks.com/movies
        'https://filmarks.com/movies/10859',
        'https://filmarks.com/movies/26669',
        'https://filmarks.com/movies/16263',#2003
        'https://filmarks.com/movies/16400',
        'https://filmarks.com/movies/32518',#2002
        'https://filmarks.com/movies/34444',#2001
        'https://filmarks.com/movies/4708',
        'https://filmarks.com/movies/15830',#2000
        'https://filmarks.com/movies/35869',#1999
        'https://filmarks.com/movies/19127',#1998
        'https://filmarks.com/movies/10955',#1997
        'https://filmarks.com/movies/34139',#1996
        'https://filmarks.com/movies/37019',#1995
        'https://filmarks.com/movies/31778',#1994


]

for url in URLS:
  response = request.urlopen(url)
  soup = BeautifulSoup(response)
  response.close()

  # レビューゾーンのスクレイピング
  # class属性が「p-content-detail__title」のspanタグを検索する
  title = soup.find('h2', class_='p-content-detail__title').find('span')
  # class属性が「p-content-detail__title」のaタグを検索する
  year = soup.find('h2', class_='p-content-detail__title').find('a')
  # class属性が「genres」のulタグを検索する
  genle = soup.find('ul', class_='genres')
  # class属性が「c-content__jacket image」のdivタグを検索する
  picture = soup.find('a', class_='c-content__jacket').find('img').get('src')
  # class属性が「p-main-area p-timeline」のdivタグを検索する
  p_main_area = soup.find('div', class_='p-main-area p-timeline')
  # class属性が「p-main-area p-content-detail-highlight__body」のdivタグを検索する
  highlight = p_main_area.find('div', class_="p-content-detail-highlight__body")
  if highlight != None:
    highlight = highlight.text

  #あとから追加します、画像データ
  wordcloud = None

  # class属性が「p-mark__review」であるdivタグを検索する
  #score = p_main_area.find_all('div', class_='c-rating__score')
  #review = p_main_area.find_all('div', class_='p-mark__review')

  #for i in range(len(review)):
  #   _df = pd.DataFrame({'score': [score[i].text],
  #                       'review': [review[i].text]})
  #   df_list.append(_df)

  _df = pd.DataFrame({'Title': [title.text],
                      'Year': [year.text],
                      'Genle': [genle.text],
                      'Picture': [picture],
                      'Highlight': [highlight],
                      'Wordcloud':[wordcloud]})
  df_list.append(_df)

  print("page%s is over"%url)

# 一つのデータフレームにまとめる
df_review = pd.concat(df_list).reset_index(drop=True)
print(df_review.shape)
df_review.head()

# スクレイピングしたデータフレームをcsv形式で保存
df_review.to_csv('movie_loveStory.csv', index=False, encoding='utf_8_sig')
# Out:
# pagehttps://filmarks.com/movies/109650 is over
# pagehttps://filmarks.com/movies/107870 is over
# pagehttps://filmarks.com/movies/98608 is over
# pagehttps://filmarks.com/movies/112693 is over
# pagehttps://filmarks.com/movies/103044 is over
# pagehttps://filmarks.com/movies/98638 is over
# pagehttps://filmarks.com/movies/100594 is over
# pagehttps://filmarks.com/movies/101624 is over
# pagehttps://filmarks.com/movies/87476 is over
# pagehttps://filmarks.com/movies/98499 is over
# pagehttps://filmarks.com/movies/95431 is over
# pagehttps://filmarks.com/movies/83976 is over
# pagehttps://filmarks.com/movies/86757 is over
# pagehttps://filmarks.com/movies/91267 is over
# pagehttps://filmarks.com/movies/79688 is over
# pagehttps://filmarks.com/movies/79781 is over
# pagehttps://filmarks.com/movies/77830 is over
# pagehttps://filmarks.com/movies/77200 is over
# pagehttps://filmarks.com/movies/69870 is over
# pagehttps://filmarks.com/movies/70080 is over
# ...
